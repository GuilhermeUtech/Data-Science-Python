# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col=0)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2000-01-01 to 2002-09-26
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       1000 non-null   float64
#  1   B       1000 non-null   float64
#  2   C       1000 non-null   float64
#  3   D       1000 non-null   float64
# dtypes: float64(4)
# memory usage: 39.1+ KB

# %%
df2 = pd.read_csv('df2')

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
#plotar área

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       10 non-null     float64
#  1   b       10 non-null     float64
#  2   c       10 non-null     float64
#  3   d       10 non-null     float64
# dtypes: float64(4)
# memory usage: 448.0 bytes

# %%
df2.plot.area()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked='true')
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.line(x=df1.index, y='B', figsize=(12,3))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-62c62364814c> in <module>
# ----> 1 df1.plot.line(x=df1.index, y='B', figsize=(12,3))
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwargs)
#    1015         as coordinates.
#    1016         """
# -> 1017         return self(kind="line", x=x, y=y, **kwargs)
#    1018
#    1019     @Appender(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     912                 if is_integer(x) and not data.columns.holds_integer():
#     913                     x = data_cols[x]
# --> 914                 elif not isinstance(data[x], ABCSeries):
#     915                     raise ValueError("x must be a label or position")
#     916                 data = data.set_index(x)
#
# ...

# %%
df1.index
# Out:
# Index(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04', '2000-01-05',
#        '2000-01-06', '2000-01-07', '2000-01-08', '2000-01-09', '2000-01-10',
#        ...
#        '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20', '2002-09-21',
#        '2002-09-22', '2002-09-23', '2002-09-24', '2002-09-25', '2002-09-26'],
#       dtype='object', length=1000)

# %%
df1.plot.scatter(x='A', y='B', c='C', cmap="inferno")
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*30)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.box()
# Out:
# <AxesSubplot:>

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(1000,2), columns=['A', 'B'])

# %%
df
# Out:
#             A         B
# 0    0.080790  0.089588
# 1    0.497621  0.322716
# 2    0.543788  0.469197
# 3    0.888200  0.780906
# 4    0.446039  0.031754
# ..        ...       ...
# 995  0.265442  0.252934
# 996  0.550738  0.750438
# 997  0.675174  0.352832
# 998  0.914848  0.320779
# 999  0.054125  0.873449
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x='A', y='B', gridsize=20, cmap="Oranges")
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# <h1>Exercícios</h1>

# %%
df3 = pd.read_csv('df3')

# %%
df3
# Out:
#             a         b         c         d
# 0    0.336272  0.325011  0.001020  0.401402
# 1    0.980265  0.831835  0.772288  0.076485
# 2    0.480387  0.686839  0.000575  0.746758
# 3    0.502106  0.305142  0.768608  0.654685
# 4    0.856602  0.171448  0.157971  0.321231
# ..        ...       ...       ...       ...
# 495  0.528705  0.226122  0.055835  0.131962
# 496  0.324730  0.215201  0.935302  0.794115
# 497  0.118036  0.264574  0.629206  0.824062
# 498  0.227021  0.660209  0.851353  0.478676
# 499  0.466157  0.753000  0.115391  0.279712
#
# [500 rows x 4 columns]

# %%
df3.plot.scatter(x='a', y='b', c='red', s=50, figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df3['a'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3['a'].plot.hist(bins=40)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3[['a','b']].plot.box()
# Out:
# <AxesSubplot:>

# %%
df3['d'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3['d'].plot.kde(linewidth=5, ls="--")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
f = plt.figure()
df3.iloc[:30].plot.area(alpha=0.5)
plt.legend()
# Out:
# <AxesSubplot:>
